# %%
import pandas as pd
import matplotlib as plt
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
df = pd.read_csv("__thoughts__/small_scale_N.csv", index_col= 0)
df
# Out:
#                    Gender  Age (in years)  Country of residence_1  \
# Participant ID
# R_OdiJe8PVveer3Zn       1              19                       0
# R_3DqIs9P59r1j91m       1              19                       0
# R_3NCJWc5lFsJxpzf       1              19                       0
# R_3EHn7EsgsNvKv8g       2              19                       0
# R_3CZ6NFiUmFAkssV       2              19                       0
# ...                   ...             ...                     ...
# R_33srhXrs4WiD2aY       1              27                       0
# R_2VPkB4PQPnP9OYv       2              68                       0
# R_2QFAUZS7vWUIgKm       2              57                       0
# R_2S2JQMmgH9O63xp       2              42                       0
# R_sj5wkGYg0nMEdKV       1              41                       0
#
#                    Country of residence_2  Country of residence_3  \
# Participant ID
# R_OdiJe8PVveer3Zn                       0                       0
# ...

# %%
#X= df[['Gender', 'Age (in years)', 'Country of residence', 'Living area',
       #'Children', 
       #'Total conform', 'Risk6', 'Education_cat', 'Job_1.0', 'Job_2.0', 'Job_3.0',
       #'Job_4.0', 'Job_5.0', 'Job_6.0', 'Job_7.0']]
#y= df[['Small-scale_NEUTRAL']]

# %%
df.describe()
# Out:
#            Gender  Age (in years)  Country of residence_1  \
# count  542.000000      542.000000              542.000000
# mean     1.523985       33.108856                0.184502
# std      0.507227       13.430080                0.388251
# min      1.000000       15.000000                0.000000
# 25%      1.000000       23.000000                0.000000
# 50%      2.000000       29.000000                0.000000
# 75%      2.000000       41.000000                0.000000
# max      3.000000       72.000000                1.000000
#
#        Country of residence_2  Country of residence_3  Country of residence_4  \
# count              542.000000              542.000000              542.000000
# mean                 0.186347                0.171587                0.271218
# std                  0.389746                0.377369                0.444999
# min                  0.000000                0.000000                0.000000
# ...

# %%
df1 = pd.read_csv("__thoughts__/workingdf.csv", index_col= 0)
df1
# Out:
#                    Gender  Age (in years)  Country of residence  Living area  \
# Participant ID
# R_OdiJe8PVveer3Zn       1              19                     4            2
# R_3DqIs9P59r1j91m       1              19                     4            2
# R_3NCJWc5lFsJxpzf       1              19                     4            2
# R_3EHn7EsgsNvKv8g       2              19                     4            2
# R_3CZ6NFiUmFAkssV       2              19                     4            2
# ...                   ...             ...                   ...          ...
# R_33srhXrs4WiD2aY       1              27                     4            2
# R_2VPkB4PQPnP9OYv       2              68                     5            2
# R_2QFAUZS7vWUIgKm       2              57                     5            2
# R_2S2JQMmgH9O63xp       2              42                     5            2
# R_sj5wkGYg0nMEdKV       1              41                     5            2
#
# ...

# %%
df1.describe()
# Out:
#            Gender  Age (in years)  Country of residence  Living area  \
# count  542.000000      542.000000            542.000000   542.000000
# mean     1.523985       33.108856              3.088561     1.811808
# std      0.507227       13.430080              1.391650     0.405153
# min      1.000000       15.000000              1.000000     1.000000
# 25%      1.000000       23.000000              2.000000     2.000000
# 50%      2.000000       29.000000              3.000000     2.000000
# 75%      2.000000       41.000000              4.000000     2.000000
# max      3.000000       72.000000              5.000000     4.000000
#
#          Children         Job  Small-scale_NEUTRAL  Large-scale_NEUTRAL  \
# count  542.000000  542.000000           542.000000           542.000000
# mean     1.463100    3.492620             1.802583             1.909594
# std      0.784275    2.457577             0.398417             0.287027
# ...

# %%
cr = pd.crosstab([df1['Small-scale_COVID19']], df1['Large-scale_COVID19'])
cr
# Out:
# Large-scale_COVID19    1    2
# Small-scale_COVID19
# 1                     71   36
# 2                    212  223

# %%
from scipy.stats import fisher_exact
oddsratio, pvalue = fisher_exact(cr)
print("oddsratio:", oddsratio, "pvalue:", pvalue)
# Out:
# oddsratio: 2.074554507337526 pvalue: 0.0011621703409700548

# %%
cr1 = pd.crosstab([df1['Small-scale_COVID19']], df1['Small-scale_NEUTRAL'])
cr1
# Out:
# Small-scale_NEUTRAL   1    2
# Small-scale_COVID19
# 1                    35   72
# 2                    72  363

# %%
oddsratio, pvalue = fisher_exact(cr1)
print("oddsratio:", oddsratio, "pvalue:", pvalue)
# Out:
# oddsratio: 2.450810185185185 pvalue: 0.0003651262938955663

# %%
cr2 = pd.crosstab([df1['Large-scale_COVID19']], df1['Large-scale_NEUTRAL'])
cr2
# Out:
# Large-scale_NEUTRAL   1    2
# Large-scale_COVID19
# 1                    29  254
# 2                    20  239

# %%
oddsratio, pvalue = fisher_exact(cr2)
print("oddsratio:", oddsratio, "pvalue:", pvalue)
# Out:
# oddsratio: 1.3643700787401576 pvalue: 0.3686791934136282

# %%
####ESTO LO VOY A HACER PARA EL TOTAL DE LOS 4 GRUPOS 
#AGE: SMALL SCALE NEUTRAL, LARGE SCALE NEUTRAL, COVID... ETC. Y TAMBIÉN CON INDIV/COLLECT)
import matplotlib.pyplot as plt
x =  df1["Age (in years)"], df1["Large-scale_NEUTRAL"], df1["Small-scale_COVID19"], df1["Large-scale_COVID19"]# create box and whisker plot
plt.boxplot(x)
# show line plot
plt.show()

# %%
# example of a scatter plot


x = df["Total conform"]
# second variable
y = df["Small-scale_NEUTRAL"]
# create scatter plot
plt.scatter(x, y)
 # show line plot
plt.show()

# %%
# calculate the pearson's correlation between two variables from numpy.random import randn
from numpy.random import seed
from scipy.stats import kendalltau# seed random number generator
seed(1)
# prepare data
data1 = df1["Small-scale_NEUTRAL"]
data2 = df1["Country of residence"]
# calculate Pearson's correlation
coef, p = kendalltau(data1, data2)
print('Kendall correlation coefficient: %.3f' % coef) # interpret the significance
alpha = 0.05
if p > alpha:
    print('Samples are uncorrelated (fail to reject H0) p=%.3f' % p) 
else:
    print('Samples are correlated (reject H0) p=%.3f' % p)
# Out:
# Kendall correlation coefficient: -0.040
# Samples are uncorrelated (fail to reject H0) p=0.295

# %%
from sklearn import cluster
import networkx as nx
from collections import defaultdict
import matplotlib.pyplot as plt
from matplotlib import cm
import seaborn as sns
import pandas as pd
import numpy as np
from sklearn.metrics.cluster import normalized_mutual_info_score
from sklearn.metrics.cluster import adjusted_rand_score

# %%
# synthetic classification dataset
from numpy import where
from sklearn.datasets import make_classification
from matplotlib import pyplot
# define dataset
X, y = make_classification(n_samples=542, n_features=6, n_informative=2, n_redundant=0, n_clusters_per_class=1, random_state=4)
# create scatter plot for samples from each class
for class_value in range(2):
	# get row indexes for samples with this class
	row_ix = where(y == class_value)
	# create scatter of these samples
	pyplot.scatter(X[row_ix, 0], X[row_ix, 1])
# show the plot
pyplot.show()

# %%
# affinity propagation clustering
from numpy import unique
from numpy import where
from sklearn.datasets import make_classification
from sklearn.cluster import AffinityPropagation
from matplotlib import pyplot
# define dataset
X, _ = make_classification(n_samples=542, n_features=5, n_informative=2, n_redundant=0, n_clusters_per_class=1, random_state=4)
# define the model
model = AffinityPropagation(damping=0.9)
# fit the model
model.fit(X)
# assign a cluster to each example
yhat = model.predict(X)
# retrieve unique clusters
clusters = unique(yhat)
# create scatter plot for samples from each cluster
for cluster in clusters:
	# get row indexes for samples with this cluster
	row_ix = where(yhat == cluster)
	# create scatter of these samples
	pyplot.scatter(X[row_ix, 0], X[row_ix, 1])
# show the plot
pyplot.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/sklearn/cluster/_affinity_propagation.py:146: FutureWarning: 'random_state' has been introduced in 0.23. It will be set to None starting from 0.25 which means that results will differ at every function call. Set 'random_state' to None to silence this warning, or to 0 to keep the behavior of versions <0.23.
#   warnings.warn(("'random_state' has been introduced in 0.23. "

# %%
df
# Out:
#                    Gender  Age (in years)  Country of residence_1  \
# Participant ID
# R_OdiJe8PVveer3Zn       1              19                       0
# R_3DqIs9P59r1j91m       1              19                       0
# R_3NCJWc5lFsJxpzf       1              19                       0
# R_3EHn7EsgsNvKv8g       2              19                       0
# R_3CZ6NFiUmFAkssV       2              19                       0
# ...                   ...             ...                     ...
# R_33srhXrs4WiD2aY       1              27                       0
# R_2VPkB4PQPnP9OYv       2              68                       0
# R_2QFAUZS7vWUIgKm       2              57                       0
# R_2S2JQMmgH9O63xp       2              42                       0
# R_sj5wkGYg0nMEdKV       1              41                       0
#
#                    Country of residence_2  Country of residence_3  \
# Participant ID
# R_OdiJe8PVveer3Zn                       0                       0
# ...

# %%
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
from sklmer import LmerRegressor
df1
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/rpy2/robjects/vectors.py:969: UserWarning: R object inheriting from "POSIXct" but without attribute "tzone".
#   warnings.warn('R object inheriting from "POSIXct" but without '
#                    Gender  Age (in years)  Country of residence  Living area  \
# Participant ID
# R_OdiJe8PVveer3Zn       1              19                     4            2
# R_3DqIs9P59r1j91m       1              19                     4            2
# R_3NCJWc5lFsJxpzf       1              19                     4            2
# R_3EHn7EsgsNvKv8g       2              19                     4            2
# R_3CZ6NFiUmFAkssV       2              19                     4            2
# ...                   ...             ...                   ...          ...
# R_33srhXrs4WiD2aY       1              27                     4            2
# R_2VPkB4PQPnP9OYv       2              68                     5            2
# ...

# %%
df1['Large-scale_COVID'] = df['Large-scale_COVID19'] -  df['Large-scale_COVID19'].mean()
random = ['0 + C(Children)', '0 + C df1['Large-scale_COVID']]
model = PoissonBayesMixedGLM.from_formula('y ~ year_cen',
                random, data)
result = model.fit()
# Out:
#   File "<ipython-input-33-58e400199c03>", line 2
#     random = ['0 + C(Children)', '0 + C df1['Large-scale_COVID']]
#                                              ^
# SyntaxError: invalid syntax

# %%
from pymer4.models import Lmer

# %%
model = Lmer('Large-scale_COVID19 ~ Country of residence + (Country of residence|Group)', data=df)
print(model.fit())
# Out:
# ---------------------------------------------------------------------------
# PackageNotInstalledError                  Traceback (most recent call last)
# <ipython-input-38-5e2ab26551ed> in <module>
#       1 model = Lmer('Large-scale_COVID19 ~ Country of residence + (Country of residence|Group)', data=df)
# ----> 2 print(model.fit())
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pymer4/models/Lmer.py in fit(self, conf_int, n_boot, factors, permute, ordered, summarize, verbose, REML, rank, rank_group, rank_exclude_cols, no_warnings, control, old_optimizer)
#     364                 )
#     365
# --> 366             lmer = importr("lmerTest")
#     367             lmc = robjects.r(f"lmerControl({control})")
#     368             self.model_obj = lmer.lmer(self.formula, data=dat, REML=REML, control=lmc)
#
# ...
